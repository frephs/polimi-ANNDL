# %% [markdown]
# ## 1. Setup and Configuration

# %%
import sys
import subprocess
from pathlib import Path

# Library installation
req_path = Path("requirements.txt")
if not req_path.exists():
    raise FileNotFoundError(f"requirements.txt not found in {Path.cwd()}")

# Ensure pip is up-to-date and install requirements using the current Python interpreter
subprocess.check_call([sys.executable, "-m", "pip", "install", "--upgrade", "pip"])
subprocess.check_call([sys.executable, "-m", "pip", "install", "-r", str(req_path)])
# Out:
# Requirement already satisfied: pip in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (25.3)
# Requirement already satisfied: numpy>=1.21.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from -r requirements.txt (line 2)) (2.3.4)
# Requirement already satisfied: pandas>=1.3.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from -r requirements.txt (line 3)) (2.3.3)
# Requirement already satisfied: matplotlib>=3.4.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from -r requirements.txt (line 4)) (3.10.7)
# Requirement already satisfied: seaborn>=0.11.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from -r requirements.txt (line 5)) (0.13.2)
# Requirement already satisfied: torch>=2.0.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from -r requirements.txt (line 8)) (2.9.0)
# Requirement already satisfied: torchvision>=0.15.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from -r requirements.txt (line 9)) (0.24.0)
# Requirement already satisfied: pyyaml>=6.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from -r requirements.txt (line 12)) (6.0.3)
# Requirement already satisfied: scikit-learn>=1.0.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from -r requirements.txt (line 15)) (1.7.2)
# Requirement already satisfied: scipy>=1.7.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from -r requirements.txt (line 16)) (1.16.3)
# Requirement already satisfied: jupyter>=1.0.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from -r requirements.txt (line 22)) (1.1.1)
# Requirement already satisfied: ipykernel>=6.0.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from -r requirements.txt (line 23)) (7.1.0)
# Requirement already satisfied: tensorboard>=2.10.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from -r requirements.txt (line 26)) (2.20.0)
# Requirement already satisfied: tqdm>=4.62.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from -r requirements.txt (line 29)) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from pandas>=1.3.0->-r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from pandas>=1.3.0->-r requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from pandas>=1.3.0->-r requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 4)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 4)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 4)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 4)) (25.0)
# Requirement already satisfied: pillow>=8 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 4)) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 4)) (3.2.5)
# Requirement already satisfied: filelock in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from torch>=2.0.0->-r requirements.txt (line 8)) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from torch>=2.0.0->-r requirements.txt (line 8)) (4.15.0)
# Requirement already satisfied: setuptools in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from torch>=2.0.0->-r requirements.txt (line 8)) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from torch>=2.0.0->-r requirements.txt (line 8)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from torch>=2.0.0->-r requirements.txt (line 8)) (3.5)
# Requirement already satisfied: jinja2 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from torch>=2.0.0->-r requirements.txt (line 8)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from torch>=2.0.0->-r requirements.txt (line 8)) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from torch>=2.0.0->-r requirements.txt (line 8)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from torch>=2.0.0->-r requirements.txt (line 8)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from torch>=2.0.0->-r requirements.txt (line 8)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from torch>=2.0.0->-r requirements.txt (line 8)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from torch>=2.0.0->-r requirements.txt (line 8)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from torch>=2.0.0->-r requirements.txt (line 8)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from torch>=2.0.0->-r requirements.txt (line 8)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from torch>=2.0.0->-r requirements.txt (line 8)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from torch>=2.0.0->-r requirements.txt (line 8)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from torch>=2.0.0->-r requirements.txt (line 8)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from torch>=2.0.0->-r requirements.txt (line 8)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from torch>=2.0.0->-r requirements.txt (line 8)) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from torch>=2.0.0->-r requirements.txt (line 8)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from torch>=2.0.0->-r requirements.txt (line 8)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from torch>=2.0.0->-r requirements.txt (line 8)) (1.13.1.3)
# Requirement already satisfied: triton==3.5.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from torch>=2.0.0->-r requirements.txt (line 8)) (3.5.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from scikit-learn>=1.0.0->-r requirements.txt (line 15)) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from scikit-learn>=1.0.0->-r requirements.txt (line 15)) (3.6.0)
# Requirement already satisfied: notebook in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jupyter>=1.0.0->-r requirements.txt (line 22)) (7.4.7)
# Requirement already satisfied: jupyter-console in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jupyter>=1.0.0->-r requirements.txt (line 22)) (6.6.3)
# Requirement already satisfied: nbconvert in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jupyter>=1.0.0->-r requirements.txt (line 22)) (7.16.6)
# Requirement already satisfied: ipywidgets in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jupyter>=1.0.0->-r requirements.txt (line 22)) (8.1.8)
# Requirement already satisfied: jupyterlab in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jupyter>=1.0.0->-r requirements.txt (line 22)) (4.4.10)
# Requirement already satisfied: comm>=0.1.1 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from ipykernel>=6.0.0->-r requirements.txt (line 23)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from ipykernel>=6.0.0->-r requirements.txt (line 23)) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from ipykernel>=6.0.0->-r requirements.txt (line 23)) (9.7.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from ipykernel>=6.0.0->-r requirements.txt (line 23)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from ipykernel>=6.0.0->-r requirements.txt (line 23)) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from ipykernel>=6.0.0->-r requirements.txt (line 23)) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from ipykernel>=6.0.0->-r requirements.txt (line 23)) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from ipykernel>=6.0.0->-r requirements.txt (line 23)) (7.1.3)
# Requirement already satisfied: pyzmq>=25 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from ipykernel>=6.0.0->-r requirements.txt (line 23)) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from ipykernel>=6.0.0->-r requirements.txt (line 23)) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from ipykernel>=6.0.0->-r requirements.txt (line 23)) (5.14.3)
# Requirement already satisfied: absl-py>=0.4 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from tensorboard>=2.10.0->-r requirements.txt (line 26)) (2.3.1)
# Requirement already satisfied: grpcio>=1.48.2 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from tensorboard>=2.10.0->-r requirements.txt (line 26)) (1.76.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from tensorboard>=2.10.0->-r requirements.txt (line 26)) (3.10)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from tensorboard>=2.10.0->-r requirements.txt (line 26)) (6.33.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from tensorboard>=2.10.0->-r requirements.txt (line 26)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from tensorboard>=2.10.0->-r requirements.txt (line 26)) (3.1.3)
# Requirement already satisfied: decorator>=4.3.2 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 23)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 23)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 23)) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 23)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 23)) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 23)) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 23)) (0.6.3)
# Requirement already satisfied: wcwidth in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 23)) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 23)) (0.8.5)
# Requirement already satisfied: platformdirs>=2.5 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=6.0.0->-r requirements.txt (line 23)) (4.5.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 23)) (0.7.0)
# Requirement already satisfied: six>=1.5 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->-r requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 23)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 23)) (3.0.0)
# Requirement already satisfied: pure-eval in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel>=6.0.0->-r requirements.txt (line 23)) (0.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from sympy>=1.13.3->torch>=2.0.0->-r requirements.txt (line 8)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from werkzeug>=1.0.1->tensorboard>=2.10.0->-r requirements.txt (line 26)) (3.0.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from ipywidgets->jupyter>=1.0.0->-r requirements.txt (line 22)) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from ipywidgets->jupyter>=1.0.0->-r requirements.txt (line 22)) (3.0.16)
# Requirement already satisfied: async-lru>=1.0.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (0.2.4)
# Requirement already satisfied: anyio in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (4.11.0)
# Requirement already satisfied: certifi in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (1.0.9)
# Requirement already satisfied: idna in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (0.23.1)
# Requirement already satisfied: send2trash>=1.8.2 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (4.25.1)
# Requirement already satisfied: requests>=2.31 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (2.32.5)
# Requirement already satisfied: sniffio>=1.1 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (25.1.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (0.28.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (4.0.0)
# Requirement already satisfied: rfc3339-validator in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (0.1.1)
# Requirement already satisfied: fqdn in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (1.5.1)
# Requirement already satisfied: isoduration in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (1.1.0)
# Requirement already satisfied: uri-template in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 22)) (4.14.2)
# Requirement already satisfied: bleach!=5.0.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 22)) (6.3.0)
# Requirement already satisfied: defusedxml in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 22)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 22)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 22)) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 22)) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 22)) (1.5.1)
# Requirement already satisfied: webencodings in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 22)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 22)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (2.21.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (2.5.0)
# Requirement already satisfied: lark>=1.2.2 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (1.3.1)
# Requirement already satisfied: cffi>=2.0.0b1 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (2.0.0)
# Requirement already satisfied: pycparser in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from cffi>=2.0.0b1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (2.23)
# Requirement already satisfied: soupsieve>1.2 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from beautifulsoup4->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 22)) (2.8)
# Requirement already satisfied: arrow>=0.15.0 in /home/frephs/GitHub/polimi-an2dl/.venv/lib64/python3.14/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->-r requirements.txt (line 22)) (1.4.0)
# 0

# %%
# =============================================================================
# SETUP AND CONFIGURATION
# =============================================================================

import os
import sys
import torch

# Import utilities from src modules
from src.utils.config import load_config
from src.utils.seed import set_seed
from src.utils.device import get_device

# Load and validate configuration
config = load_config('configs/default_config.yaml', validate=False)

# Set random seed for reproducibility
set_seed(config['seed'])

# Get device (GPU if available, else CPU)
device = get_device("auto")

print("\n" + "="*80)
print("CONFIGURATION LOADED")
print("="*80)
print(f"Experiment: {config['logging']['experiment_name']}")
print(f"Seed: {config['seed']}")
print(f"Device: {device}")
print("="*80)
# Out:
# Using device: cpu
#
# ================================================================================
# CONFIGURATION LOADED
# ================================================================================
# Experiment: oversampling_B_rnn
# Seed: 42
# Device: cpu
# ================================================================================

# %% [markdown]
# ## 2. Data Loading

# %%
import pandas as pd
import numpy as np

# Load raw data
data_config = config['data']
X_train = pd.read_csv(os.path.join(data_config['raw_dir'], data_config['train_file']))
y_train = pd.read_csv(os.path.join(data_config['raw_dir'], data_config['train_labels_file']))
X_test = pd.read_csv(os.path.join(data_config['raw_dir'], data_config['test_file']))

print("="*80)
print("DATA LOADING")
print("="*80)
print(f"Training data shape: {X_train.shape}")
print(f"Training labels shape: {y_train.shape}")
print(f"Test data shape: {X_test.shape}")

# Check class distribution
print("\nClass distribution:")
for label, count in y_train['label'].value_counts().sort_index().items():
    pct = count / len(y_train) * 100
    print(f"  {label}: {count:4d} samples ({pct:5.2f}%)")
print("="*80)
# Out:
# ================================================================================
# DATA LOADING
# ================================================================================
# Training data shape: (105760, 40)
# Training labels shape: (661, 2)
# Test data shape: (211840, 40)
#
# Class distribution:
#   high_pain:   56 samples ( 8.47%)
#   low_pain:   94 samples (14.22%)
#   no_pain:  511 samples (77.31%)
# ================================================================================

# %% [markdown]
# ## 3. Data Preprocessing
#
# Apply all preprocessing steps defined in the configuration:
# - Fix skewed features
# - Drop constant/redundant features
# - Combine highly correlated features
# - Create prosthesis indicator
# - Map labels to integers

# %%
from src.preprocessing.utils import preprocess_pirates_data

# Preprocess data according to config
X_train, y_train = preprocess_pirates_data(X_train, y_train, config, verbose=True)

# Save processed data
os.makedirs(config['data']['processed_dir'], exist_ok=True)
X_train.to_csv(os.path.join(config['data']['processed_dir'], 'X_train_processed.csv'), index=False)
y_train.to_csv(os.path.join(config['data']['processed_dir'], 'y_train_processed.csv'), index=False)

print(f"\n✓ Processed data saved to {config['data']['processed_dir']}")
# Out:
# ================================================================================
# PREPROCESSING PIRATES PAIN DATA
# ================================================================================
# ================================================================================
# TIME FEATURE ENGINEERING
# ================================================================================
# ✓ Added cyclical position features (sin/cos)
# ✓ Added cyclical hour features (sin/cos)
# ✓ Added cyclical day of week features (sin/cos)
#
# Total time features added: 6
# New shape: (105760, 46)
# ================================================================================
# Dropped feature: joint_30
# Combined joint_00 and joint_02 → joint_00_02
# Combined joint_01 and joint_03 → joint_01_03
# Combined joint_10 and joint_11 → joint_10_11
# Created has_prosthesis feature from body part indicators
# Mapped labels: {'no_pain': 0, 'low_pain': 1, 'high_pain': 2}
#
# Final shape: (105760, 40)
# ================================================================================
#
# ✓ Processed data saved to ../data/processed

# %% [markdown]
# ## 4. Train-Validation Split

# %%
from src.preprocessing.utils import split_train_val

# Split into train and validation sets with stratification
X_train_split, X_val_split, y_train_split, y_val_split = split_train_val(
    X_train,
    y_train,
    val_size=config['split']['val_size'],
    stratify=config['split']['stratify'],
    seed=config['seed']
)
# Out:
# Stratified split by user labels:
#   Train users: 561 (85.0%)
#   Val users:   100 (15.0%)
#
# Train: 89760 samples from 561 users
#   Class 0: 77.36%
#   Class 1: 14.26%
#   Class 2:  8.38%
#
# Val:   16000 samples from 100 users
#   Class 0: 77.00%
#   Class 1: 14.00%
#   Class 2:  9.00%

# %% [markdown]
# ## 5. Feature Normalization

# %%
from src.preprocessing.utils import normalize_features
from sklearn.preprocessing import MinMaxScaler

# Get feature columns to normalize (exclude metadata and label columns)
exclude_cols = ['sample_index', 'time', 'label']

# Also exclude categorical indicators if they exist
if 'has_prosthesis' in X_train_split.columns:
    exclude_cols.append('has_prosthesis')

# CRITICAL FIX: Exclude time features from normalization (they're already in proper range)
# Time features are in [-1, 1] and should NOT be normalized to [0, 1]
time_feature_cols = [col for col in X_train_split.columns 
                     if any(x in col for x in ['time_position', 'hour_', 'day_of_week_', 'day_of_month_'])]
if len(time_feature_cols) > 0:
    exclude_cols.extend(time_feature_cols)
    print(f"⚠️  Excluding {len(time_feature_cols)} time features from normalization:")
    print(f"   {time_feature_cols}")

feature_columns = [col for col in X_train_split.columns if col not in exclude_cols]

print(f"Normalizing {len(feature_columns)} features using min-max scaling")
print(f"Features: {feature_columns[:5]}... (showing first 5)")

# Normalize features (fit on train, apply to both train and val)
X_train_norm, X_val_norm = normalize_features(X_train_split, X_val_split, feature_columns)

# IMPORTANT: Store the scaler for later use on test data
# This prevents data leakage by ensuring test data uses TRAINING statistics
scaler = MinMaxScaler()
scaler.fit(X_train_split[feature_columns])

print(f"\n✓ Features normalized and scaler saved for test data")
print(f"  Train range: [{X_train_norm[feature_columns].min().min():.4f}, {X_train_norm[feature_columns].max().max():.4f}]")
print(f"  Val range: [{X_val_norm[feature_columns].min().min():.4f}, {X_val_norm[feature_columns].max().max():.4f}]")
# Out:
# ⚠️  Excluding 6 time features from normalization:
#    ['time_position', 'time_position_sin', 'hour_sin', 'hour_cos', 'day_of_week_sin', 'day_of_week_cos']
# Normalizing 31 features using min-max scaling
# Features: ['pain_survey_1', 'pain_survey_2', 'pain_survey_3', 'pain_survey_4', 'joint_04']... (showing first 5)
#
# ✓ Features normalized and scaler saved for test data
#   Train range: [0.0000, 1.0000]
#   Val range: [-0.0020, 1.3906]

# %% [markdown]
# ## 6. Sequence Building
#
# Create sliding window sequences for time series classification.

# %%
# Verify that feature scaling is correct
print("="*80)
print("FEATURE SCALING VERIFICATION")
print("="*80)

# Check regular features
print(f"\n✓ Regular features ({len(feature_columns)} features):")
print(f"  Train range: [{X_train_norm[feature_columns].min().min():.6f}, {X_train_norm[feature_columns].max().max():.6f}]")
print(f"  Val range:   [{X_val_norm[feature_columns].min().min():.6f}, {X_val_norm[feature_columns].max().max():.6f}]")
print(f"  Expected: [0.000000, 1.000000]")

# Check time features if they exist
if len(time_feature_cols) > 0:
    print(f"\n✓ Time features ({len(time_feature_cols)} features):")
    print(f"  Features: {time_feature_cols}")
    print(f"  Train range: [{X_train_norm[time_feature_cols].min().min():.6f}, {X_train_norm[time_feature_cols].max().max():.6f}]")
    print(f"  Val range:   [{X_val_norm[time_feature_cols].min().min():.6f}, {X_val_norm[time_feature_cols].max().max():.6f}]")
    print(f"  Expected: [-1.000000, 1.000000]")
    
    # Check if any time features were incorrectly normalized
    incorrect = []
    for col in time_feature_cols:
        if X_train_norm[col].min() >= 0:  # Should have negative values
            incorrect.append(col)
    
    if incorrect:
        print(f"\n  ⚠️  WARNING: These time features may have been normalized incorrectly:")
        print(f"     {incorrect}")
    else:
        print(f"\n  ✅ All time features have correct range (includes negative values)")
else:
    print(f"\nℹ️  No time features detected (time_features.enabled = False in config)")

print("="*80)
# Out:
# ================================================================================
# FEATURE SCALING VERIFICATION
# ================================================================================
#
# ✓ Regular features (31 features):
#   Train range: [0.000000, 1.000000]
#   Val range:   [-0.002006, 1.390628]
#   Expected: [0.000000, 1.000000]
#
# ✓ Time features (6 features):
#   Features: ['time_position', 'time_position_sin', 'hour_sin', 'hour_cos', 'day_of_week_sin', 'day_of_week_cos']
#   Train range: [-1.000000, 1.000000]
#   Val range:   [-1.000000, 1.000000]
#   Expected: [-1.000000, 1.000000]
#
#   ⚠️  WARNING: These time features may have been normalized incorrectly:
#      ['time_position']
# ================================================================================

# %% [markdown]
# ## 6. Sequence Building
#
# Create sliding window sequences for time series classification.

# %%
from src.preprocessing.utils import build_sequences

# Merge features with labels for sequence building
df_train = pd.merge(X_train_norm, y_train_split, on='sample_index', how='inner')
df_val = pd.merge(X_val_norm, y_val_split, on='sample_index', how='inner')

all_feature_columns = [col for col in X_train_norm.columns if col not in ['sample_index', 'time', 'label']]
print(f"Total features for model: {len(all_feature_columns)}")
if len(time_feature_cols) > 0:
    print(f"  - Normalized features: {len(feature_columns)}")
    print(f"  - Time features: {len(time_feature_cols)}")

# Convert to float32 for memory efficiency
df_train[all_feature_columns] = df_train[all_feature_columns].astype(np.float32)
df_val[all_feature_columns] = df_val[all_feature_columns].astype(np.float32)

# Build sequences with sliding windows
print("="*80)
print("SEQUENCE BUILDING")
print("="*80)
print(f"Window size: {config['sequences']['window_size']}")
print(f"Stride: {config['sequences']['stride']}")
print()

X_train_seq, y_train_seq = build_sequences(
    df_train,
    window=config['sequences']['window_size'],
    stride=config['sequences']['stride'],
    feature_columns=all_feature_columns  # FIXED: Use ALL features
)

X_val_seq, y_val_seq = build_sequences(
    df_val,
    window=config['sequences']['window_size'],
    stride=config['sequences']['stride'],
    feature_columns=all_feature_columns  # FIXED: Use ALL features
)

print(f"✓ Sequences built successfully")
print(f"  Training sequences: {X_train_seq.shape} (samples, timesteps, features)")
print(f"  Validation sequences: {X_val_seq.shape}")
print(f"  Number of features: {X_train_seq.shape[2]}")
print(f"  Number of classes: {len(np.unique(y_train_seq))}")

# Update config with inferred values
config['model']['input_size'] = X_train_seq.shape[2]
config['model']['num_classes'] = len(np.unique(y_train_seq))
print("="*80)
# Out:
# Total features for model: 38
#   - Normalized features: 31
#   - Time features: 6
# ================================================================================
# SEQUENCE BUILDING
# ================================================================================
# Window size: 10
# Stride: 5
#
# Built 17391 sequences from 561 users
# Sequence shape: (17391, 10, 38)
# Built 3100 sequences from 100 users
# Sequence shape: (3100, 10, 38)
# ✓ Sequences built successfully
#   Training sequences: (17391, 10, 38) (samples, timesteps, features)
#   Validation sequences: (3100, 10, 38)
#   Number of features: 38
#   Number of classes: 3
# ================================================================================

# %%
from src.preprocessing.utils import oversample_minority_classes

print("="*80)
print("DATA AUGMENTATION & OVERSAMPLING")
print("="*80)

# Show original class distribution
print("\n📊 Class Distribution BEFORE Oversampling:")
unique_train, counts_train = np.unique(y_train_seq, return_counts=True)
for cls, count in zip(unique_train, counts_train):
    print(f"  Class {cls}: {count:5d} samples ({count/len(y_train_seq)*100:5.2f}%)")

# Apply oversampling if enabled in config
if config['augmentation']['enabled'] and config['augmentation']['oversample']:
    # Prepare augmentation parameters
    augment_params = {
        'noise_level': config['augmentation']['noise_level'],
        'scale_range': tuple(config['augmentation']['scale_range']),
        'shift_range': config['augmentation']['shift_range'],
        'apply_noise': config['augmentation']['apply_noise'],
        'apply_scaling': config['augmentation']['apply_scaling'],
        'apply_shift': config['augmentation']['apply_shift']
    }
    
    print(f"\n🔧 Augmentation Settings:")
    print(f"  Target Distribution: {config['augmentation']['target_distribution']}")
    print(f"  Augment Duplicates: {config['augmentation']['augment_duplicates']}")
    print(f"  Noise Level: {config['augmentation']['noise_level']}")
    print(f"  Scale Range: {config['augmentation']['scale_range']}")
    print(f"  Shift Range: ±{config['augmentation']['shift_range']} timesteps")
    print()
    
    # Apply oversampling with augmentation
    X_train_seq, y_train_seq = oversample_minority_classes(
        X_train_seq,
        y_train_seq,
        target_distribution=config['augmentation']['target_distribution'],
        augment=config['augmentation']['augment_duplicates'],
        augment_params=augment_params,
        seed=config['seed']
    )
    
    print("\n✅ Augmentation complete!")
else:
    print("\n⚠️  Augmentation disabled in config")
    print("   Set augmentation.enabled=True and augmentation.oversample=True to enable")

# Update config with final values
config['model']['input_size'] = X_train_seq.shape[2]
config['model']['num_classes'] = len(np.unique(y_train_seq))
print("="*80)
# Out:
# ================================================================================
# DATA AUGMENTATION & OVERSAMPLING
# ================================================================================
#
# 📊 Class Distribution BEFORE Oversampling:
#   Class 0: 13454 samples (77.36%)
#   Class 1:  2480 samples (14.26%)
#   Class 2:  1457 samples ( 8.38%)
#
# 🔧 Augmentation Settings:
#   Target Distribution: balanced
#   Augment Duplicates: True
#   Noise Level: 0.005
#   Scale Range: [0.98, 1.02]
#   Shift Range: ±5 timesteps
#
# Oversampling to balanced distribution:
# Target count per class: 5797
#   Class 0: 13454 (no oversampling needed)
#   Class 1: 2480 → 5797 (+3317 samples)
#   Class 2: 1457 → 5797 (+4340 samples)
#
# Final dataset size: 25048 samples
# Final class distribution:
#   Class 0: 13454 samples (53.71%)
#   Class 1:  5797 samples (23.14%)
#   Class 2:  5797 samples (23.14%)
#
# ✅ Augmentation complete!
# ================================================================================

# %% [markdown]
# ## 7. Create DataLoaders

# %%
from src.preprocessing.dataloaders import create_dataloaders
from sklearn.utils.class_weight import compute_class_weight

# Compute class weights for handling class imbalance
class_weights = compute_class_weight(
    'balanced',
    classes=np.unique(y_train_seq),
    y=y_train_seq
)
class_weights_tensor = torch.FloatTensor(class_weights).to(device)

print("="*80)
print("CLASS WEIGHTS (for loss function)")
print("="*80)
for i, (cls, cnt) in enumerate(zip(*np.unique(y_train_seq, return_counts=True))):
    print(f"  Class {cls}: {cnt:5d} samples ({cnt/len(y_train_seq)*100:5.2f}%) → weight: {class_weights[i]:.4f}")
print("="*80)

# Create dummy test data (we'll use validation for now since test has no labels)
X_test_seq, y_test_seq = X_val_seq, y_val_seq

# Auto-detect pin_memory based on device (only useful for CUDA)
pin_memory = config['dataloader']['pin_memory'] and (device.type == 'cuda')
if config['dataloader']['pin_memory'] and device.type != 'cuda':
    print(f"\n⚠️  pin_memory disabled (only useful with GPU/CUDA)")

# Create DataLoaders
train_loader, val_loader, test_loader = create_dataloaders(
    X_train_seq, y_train_seq,
    X_val_seq, y_val_seq,
    X_test_seq, y_test_seq,
    batch_size=config['training']['batch_size'],
    num_workers=config['dataloader']['num_workers'],
    shuffle=config['dataloader']['shuffle_train'],
    drop_last=config['dataloader']['drop_last'],
    pin_memory=pin_memory  # Auto-detected based on device
)

print(f"\n✓ DataLoaders created")
print(f"  Train batches: {len(train_loader)} (total samples: {len(train_loader.dataset)})")
print(f"  Val batches: {len(val_loader)} (total samples: {len(val_loader.dataset)})")
print(f"  Test batches: {len(test_loader)} (total samples: {len(test_loader.dataset)})")
print(f"  pin_memory: {pin_memory}")

# Check a batch
for xb, yb in train_loader:
    print(f"\nSample batch:")
    print(f"  Input shape: {xb.shape} (batch_size, timesteps, features)")
    print(f"  Labels shape: {yb.shape}")
    break
# Out:
# ================================================================================
# CLASS WEIGHTS (for loss function)
# ================================================================================
#   Class 0: 13454 samples (53.71%) → weight: 0.6206
#   Class 1:  5797 samples (23.14%) → weight: 1.4403
#   Class 2:  5797 samples (23.14%) → weight: 1.4403
# ================================================================================
#
# ✓ DataLoaders created
#   Train batches: 392 (total samples: 25048)
#   Val batches: 49 (total samples: 3100)
#   Test batches: 49 (total samples: 3100)
#   pin_memory: False
#
# Sample batch:
#   Input shape: torch.Size([64, 10, 38]) (batch_size, timesteps, features)
#   Labels shape: torch.Size([64])

# %% [markdown]
# ## 8. Model Creation
#
# Create the model from configuration.

# %%
import torch.nn as nn
from src.models.rnn_models import RecurrentNet

print("="*80)
print("MODEL CREATION")
print("="*80)

# Create model from config
model = RecurrentNet(
    input_size=config['model']['input_size'],
    hidden_size=config['model']['hidden_size'],
    num_layers=config['model']['num_layers'],
    num_classes=config['model']['num_classes'],
    rnn_type=config['model']['rnn_type'],
    bidirectional=config['model']['bidirectional'],
    dropout_rate=config['model']['dropout_rate'],
    task=config['model']['task'],
    use_conv1d=config['model'].get('use_conv1d', False),
    conv1d_filters=config['model'].get('conv1d_filters', [64, 128]),
    conv1d_kernel_sizes=config['model'].get('conv1d_kernel_sizes', [3, 3]),
    conv1d_dropout=config['model'].get('conv1d_dropout', 0.1)
).to(device)

print(f"✓ Model created: {config['model']['rnn_type']}")
print(f"  Architecture: {config['model']['rnn_type']} ")
print(f"  Hidden size: {config['model']['hidden_size']}")
print(f"  Num layers: {config['model']['num_layers']}")
print(f"  Bidirectional: {config['model']['bidirectional']}")
print(f"  Dropout: {config['model']['dropout_rate']}")
if config['model'].get('use_conv1d', False):
    print(f"  Conv1D enabled: {config['model'].get('conv1d_filters', [])}")
print(f"\n  Total parameters: {sum(p.numel() for p in model.parameters()):,}")
print(f"  Trainable parameters: {sum(p.numel() for p in model.parameters() if p.requires_grad):,}")
print("="*80)
# Out:
# ================================================================================
# MODEL CREATION
# ================================================================================
# ✓ Model created: LSTM
#   Architecture: LSTM
#   Hidden size: 256
#   Num layers: 1
#   Bidirectional: True
#   Dropout: 0.4
#   Conv1D enabled: [64, 128]
#
#   Total parameters: 825,028
#   Trainable parameters: 825,028
# ================================================================================

# %% [markdown]
# ## 9. Training Setup
#
# ⚠️ **Important Notes:**
# - If you re-run this cell, the previous TensorBoard writer will be closed to prevent duplicate logs
# - The scheduler is managed internally by the Trainer class
# - Mixed precision (AMP) is only enabled when using GPU (CUDA)

# %%
from torch.utils.tensorboard import SummaryWriter
from datetime import datetime
from src.utils import generate_experiment_name
from src.training import LabelSmoothingCrossEntropy
from src.training import FocalLoss

print("="*80)
print("TRAINING SETUP")
print("="*80)

# Create class-weighted loss function for handling imbalanced data

if config['training']['focal_loss']['enabled']:
    criterion = FocalLoss(
        alpha=config['training']['focal_loss']['alpha'],
        gamma=config['training']['focal_loss']['gamma']
    )
elif config['training']['label_smoothing'] > 0:
    criterion = LabelSmoothingCrossEntropy(weight=class_weights_tensor, smoothing=config['training']['label_smoothing'])
else:
    criterion = nn.CrossEntropyLoss(weight=class_weights_tensor)
    
# Create optimizer with L2 regularization (weight decay)
optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=config['training']['learning_rate'],
    weight_decay=config['training']['l2_lambda']
)

# Create TensorBoard writer
try:
    if 'writer' in locals() and writer is not None:
        writer.close()
        print("  Closed previous TensorBoard writer")
except:
    pass

os.makedirs(config['logging']['tensorboard_dir'], exist_ok=True)

# Generate descriptive experiment name based on config
experiment_name = generate_experiment_name(config)
print(f"  Generated experiment name: {experiment_name}")

writer = SummaryWriter(os.path.join(config['logging']['tensorboard_dir'], experiment_name))

print(f"✓ Training setup complete")
print(f"  Optimizer: AdamW (lr={config['training']['learning_rate']}, weight_decay={config['training']['l2_lambda']})")
print(f"  Loss function: CrossEntropyLoss (class-weighted)")
print(f"  Scheduler: {'Enabled' if config['training']['scheduler']['enabled'] else 'Disabled'} (managed by Trainer)")
print(f"  TensorBoard: {experiment_name}")
print("="*80)
# Out:
# ================================================================================
# TRAINING SETUP
# ================================================================================
#   Generated experiment name: LSTM_bi_256h_1l_0.0003lr_d040_20251117_160611
# ✓ Training setup complete
#   Optimizer: AdamW (lr=0.0003, weight_decay=0.0001)
#   Loss function: CrossEntropyLoss (class-weighted)
#   Scheduler: Enabled (managed by Trainer)
#   TensorBoard: LSTM_bi_256h_1l_0.0003lr_d040_20251117_160611
# ================================================================================

# %% [markdown]
# ## 10. Model Training
#
# Train the model using the Trainer class.
#
# ⚠️ **Note:** If you need to re-run training, it's recommended to restart the kernel and run all cells from the beginning to avoid state issues.

# %%
from src.training.trainer import Trainer

# Create trainer with all components
trainer = Trainer(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    criterion=criterion,
    optimizer=optimizer,
    device=device,
    config=config,
    writer=writer,
    experiment_name=experiment_name,
    task=config['model']['task']
)

# Train model
print("\n" + "="*80)
print("TRAINING")
print("="*80)
print(f"Epochs: {config['training']['epochs']}")
print(f"Batch size: {config['training']['batch_size']}")
print(f"Early stopping patience: {config['training']['patience']}")
print(f"Evaluation metric: {config['training']['evaluation_metric']}")
print("="*80 + "\n")

history = trainer.fit()

print("\n" + "="*80)
print("✅ TRAINING COMPLETE")
print("="*80)
# Out:
# ================================================================================
# TRAINING
# ================================================================================
# Epochs: 500
# Batch size: 64
# Early stopping patience: 50
# Evaluation metric: val_f1
# ================================================================================
#
# Training for 500 epochs...
# Task: CLASSIFICATION | Primary metric: F1
# Device: cpu | Mixed Precision: Disabled (CPU only)
# Logging to TensorBoard: True
# Models will be saved to: ./models
# --------------------------------------------------------------------------------
# Epoch   1/500 | Train: Loss=0.7387, F1=0.7472 | Val: Loss=0.5768, F1=0.8162
# ✓ New best F1: 0.8162
# ✓ New best F1: 0.8465
# ✓ New best F1: 0.8665
# ✓ New best F1: 0.8795
# ✓ New best F1: 0.8822
# ✓ New best F1: 0.8938
# ✓ New best F1: 0.9019
# ✓ New best F1: 0.9019
# Epoch  10/500 | Train: Loss=0.1194, F1=0.9749 | Val: Loss=0.4870, F1=0.9058
# ✓ New best F1: 0.9058
# ✓ New best F1: 0.9142
# ✓ New best F1: 0.9194
# ✓ New best F1: 0.9285
# Epoch  20/500 | Train: Loss=0.0761, F1=0.9869 | Val: Loss=0.4619, F1=0.9196
# Epoch  30/500 | Train: Loss=0.0612, F1=0.9893 | Val: Loss=0.5364, F1=0.9055
# ✓ New best F1: 0.9326
# Epoch  40/500 | Train: Loss=0.0526, F1=0.9920 | Val: Loss=0.4761, F1=0.9240
# Epoch  50/500 | Train: Loss=0.0472, F1=0.9930 | Val: Loss=0.5618, F1=0.9172
# Epoch  60/500 | Train: Loss=0.0468, F1=0.9930 | Val: Loss=0.5749, F1=0.9141
# ✓ New best F1: 0.9326
# Epoch  70/500 | Train: Loss=0.0404, F1=0.9945 | Val: Loss=0.5101, F1=0.9190
# Epoch  80/500 | Train: Loss=0.0322, F1=0.9968 | Val: Loss=0.5042, F1=0.9247
# ✓ New best F1: 0.9362
# Epoch  90/500 | Train: Loss=0.0306, F1=0.9967 | Val: Loss=0.4525, F1=0.9283
# Epoch 100/500 | Train: Loss=0.0295, F1=0.9966 | Val: Loss=0.4916, F1=0.9286
# Epoch 110/500 | Train: Loss=0.0292, F1=0.9961 | Val: Loss=0.5247, F1=0.9260
# Epoch 120/500 | Train: Loss=0.0271, F1=0.9968 | Val: Loss=0.4828, F1=0.9293
# ✓ New best F1: 0.9372
# Epoch 130/500 | Train: Loss=0.0278, F1=0.9961 | Val: Loss=0.5637, F1=0.9258
# Epoch 140/500 | Train: Loss=0.0265, F1=0.9968 | Val: Loss=0.4934, F1=0.9310
# Epoch 150/500 | Train: Loss=0.0257, F1=0.9971 | Val: Loss=0.4530, F1=0.9313
# Epoch 160/500 | Train: Loss=0.0262, F1=0.9964 | Val: Loss=0.5540, F1=0.9308
# Epoch 170/500 | Train: Loss=0.0203, F1=0.9980 | Val: Loss=0.5321, F1=0.9322
#
# Early stopping triggered after 175 epochs.
# Best F1: 0.9372 at epoch 125
#
# ✓ Best model saved to: LSTM_bi_256h_1l_0.0003lr_d040_20251117_160611_20251117_160611_epoch125_best_f10_9372.pt
#   Epoch: 125 | F1: 0.9372
# ✓ Best model weights restored
# ✓ TensorBoard logs saved
# --------------------------------------------------------------------------------
# Training complete!
#
# ================================================================================
# ✅ TRAINING COMPLETE
# ================================================================================

# %% [markdown]
# ## 11. Training Visualization

# %%
from src.training.metrics import plot_training_history

# Plot training history
plot_training_history(
    history,
    task=config['model']['task'],
    save_path=None
)

# %% [markdown]
# ## 12. Model Evaluation

# %%
from src.evaluation.evaluate import evaluate_and_report

# Define class names for better visualization
class_names = ['No Pain', 'Low Pain', 'High Pain']

print("\n" + "="*80)
print("MODEL EVALUATION")
print("="*80)

# Evaluate on validation set
val_metrics = evaluate_and_report(
    model=model,
    data_loader=val_loader,
    device=device,
    dataset_name="Validation",
    task=config['model']['task'],
    class_names=class_names,
    plot_cm=True
)

print("="*80)
# Out:
# ================================================================================
# MODEL EVALUATION
# ================================================================================
#
# Validation Metrics:
# ==================================================
# Accuracy:  0.9323
# Precision: 0.9297
# Recall:    0.9323
# F1 Score:  0.9291
# ==================================================
# ================================================================================

# %%
from src.evaluation.evaluate import evaluate_model
from sklearn.metrics import classification_report
import torch
import numpy as np
from tqdm.auto import tqdm # Used for a progress bar, optional

model.eval()
model.to(device) 


preds, targets = evaluate_model(model, val_loader, device, config['model']['task'])

print("\n" + "="*80)
print("DETAILED PER-CLASS EVALUATION")
print("="*80)

class_names = ['No Pain', 'Low Pain', 'High Pain']

# Generate the report
report = classification_report(
    y_true=targets, 
    y_pred=preds, 
    target_names=class_names, 
    digits=4,
    zero_division=0
)

print(report)
print("="*80)
# Out:
# ================================================================================
# DETAILED PER-CLASS EVALUATION
# ================================================================================
#               precision    recall  f1-score   support
#
#      No Pain     0.9397    0.9799    0.9594      2387
#     Low Pain     0.9403    0.8710    0.9043       434
#    High Pain     0.8278    0.6201    0.7090       279
#
#     accuracy                         0.9323      3100
#    macro avg     0.9026    0.8236    0.8576      3100
# weighted avg     0.9297    0.9323    0.9291      3100
#
# ================================================================================

# %% [markdown]
# ## 12.a. Cross-Validation (Optional)
#
# Perform K-fold cross-validation if enabled in config.

# %%
if config['cross_validation']['enabled']:
    from src.training.cross_validation import k_fold_cross_validation, plot_cv_results
    from src.models.rnn_models import RecurrentNet
    
    print("\n" + "="*80)
    print("CROSS-VALIDATION")
    print("="*80)
    print(f"K-folds: {config['cross_validation']['k_folds']}")
    print(f"Using entire training set (before train/val split)")
    print()
    
    # Prepare base model parameters
    base_model_params = {
        'input_size': config['model']['input_size'],
        'hidden_size': config['model']['hidden_size'],
        'num_layers': config['model']['num_layers'],
        'num_classes': config['model']['num_classes'],
        'rnn_type': config['model']['rnn_type'],
        'bidirectional': config['model']['bidirectional'],
        'dropout_rate': config['model']['dropout_rate'],
        'task': config['model']['task']
    }
    
    # Prepare base trainer parameters
    base_trainer_params = {
        'epochs': config['training']['epochs'],
        'batch_size': config['training']['batch_size'],
        'learning_rate': config['training']['learning_rate'],
        'weight_decay': config['training']['l2_lambda'],
        'patience': config['training']['patience'],
        'device': device,
        'optimizer': 'AdamW',
        'verbose': config['training']['verbose']
    }
    
    # Run K-fold cross-validation
    fold_losses, fold_metrics, best_scores = k_fold_cross_validation(
        X=X_train_seq,
        y=y_train_seq,
        model_class=RecurrentNet,
        base_model_params=base_model_params,
        base_trainer_params=base_trainer_params,
        k=config['cross_validation']['k_folds'],
        seed=config['seed'],
        use_class_weights=True,
        verbose=True
    )
    
    print("\n" + "="*80)
    print("📊 CROSS-VALIDATION SUMMARY")
    print("="*80)
    print(f"Mean F1: {best_scores['mean']:.4f} ± {best_scores['std']:.4f}")
    print(f"Min F1:  {min([best_scores[f'fold_{i}'] for i in range(config['cross_validation']['k_folds'])]):.4f}")
    print(f"Max F1:  {max([best_scores[f'fold_{i}'] for i in range(config['cross_validation']['k_folds'])]):.4f}")
    print("="*80)
    
    # Visualize results
    plot_cv_results(fold_metrics, k=config['cross_validation']['k_folds'])
else:
    print("\n⚠️  Cross-validation disabled in config")
    print("   Set cross_validation.enabled=True to run K-fold cross-validation")
# Out:
# ⚠️  Cross-validation disabled in config
#    Set cross_validation.enabled=True to run K-fold cross-validation

# %% [markdown]
# ## 12.b. Hyperparameter Tuning (Optional)
#
# Perform grid search over hyperparameters if enabled in config.

# %%
if config['hyperparameter_tuning']['enabled']:
    from src.training.cross_validation import grid_search_hyperparameters, plot_grid_search_results
    from src.models.rnn_models import RecurrentNet
    
    print("\n" + "="*80)
    print("HYPERPARAMETER TUNING")
    print("="*80)
    print("⚠️  WARNING: This is very time-consuming!")
    print("\nParameter Grid:")
    for param, values in config['hyperparameter_tuning']['param_grid'].items():
        print(f"  {param}: {values}")
    
    # Calculate total combinations
    param_grid = config['hyperparameter_tuning']['param_grid']
    total_combinations = 1
    for values in param_grid.values():
        total_combinations *= len(values)
    
    print(f"\nTotal combinations: {total_combinations}")
    print(f"Total training runs: {total_combinations * 5} (with 5-fold CV)")
    print()
    
    # Ask for confirmation
    proceed = input("Proceed with hyperparameter tuning? (yes/no): ").lower().strip()
    
    if proceed == 'yes':
        # Prepare base model parameters
        base_model_params = {
            'input_size': config['model']['input_size'],
            'num_classes': config['model']['num_classes'],
            'rnn_type': config['model']['rnn_type'],
            'bidirectional': config['model']['bidirectional'],
            'task': config['model']['task']
        }
        
        # Prepare base trainer parameters (add save_dir to save in models/tuning)
        base_trainer_params = {
            'epochs': config['training']['epochs'],
            'batch_size': config['training']['batch_size'],
            'weight_decay': config['training']['l2_lambda'],
            'patience': config['training']['patience'],
            'device': device,
            'optimizer': config['training']['optimizer'],
            'verbose': 10,
            'save_dir': config['logging']['save_dir']  # Save tuning models to configured directory
        }
        
        # Run grid search with cross-validation
        all_results, best_params, best_score = grid_search_hyperparameters(
            X=X_train_seq,
            y=y_train_seq,
            model_class=RecurrentNet,
            param_grid=param_grid,
            base_model_params=base_model_params,
            base_trainer_params=base_trainer_params,
            cv_k=5,
            cv_seed=config['seed'],
            use_class_weights=True,
            verbose=True
        )
        
        print("\n" + "="*80)
        print("🏆 HYPERPARAMETER TUNING RESULTS")
        print("="*80)
        print(f"Best Mean F1 Score: {best_score:.4f}")
        print("\nBest Parameters:")
        for param, value in best_params.items():
            print(f"  {param}: {value}")
        print("="*80)
        
        # Visualize results
        plot_grid_search_results(all_results, top_n=min(10, len(all_results)))
        
        print("\n💡 To use these parameters, update your config file with the best values above")
    else:
        print("❌ Hyperparameter tuning cancelled")
else:
    print("\n⚠️  Hyperparameter tuning disabled in config")
    print("   Set hyperparameter_tuning.enabled=True to run grid search")
    print("   WARNING: This is very time-consuming!")
# Out:
# ⚠️  Hyperparameter tuning disabled in config
#    Set hyperparameter_tuning.enabled=True to run grid search
#    WARNING: This is very time-consuming!

# %% [markdown]
# ## 13. Save Final Results

# %%
import json

print("\n" + "="*80)
print("SAVING RESULTS")
print("="*80)

# Create save directory
os.makedirs(config['logging']['save_dir'], exist_ok=True)

# Get final F1 score for filename
final_f1 = val_metrics.get('f1', 0.0)

# Generate descriptive results filename including F1 score
results_name = generate_experiment_name(config, f1_score=final_f1)
print(f"Results file: {results_name}_results.json")

# Save final results
results = {
    'experiment_name': experiment_name,
    'config': config,
    'val_metrics': val_metrics,
    'model_architecture': str(model),
    'total_parameters': sum(p.numel() for p in model.parameters())
}

results_path = os.path.join(config['logging']['save_dir'], f'{results_name}_results.json')
with open(results_path, 'w') as f:
    # Convert numpy types to native Python types for JSON serialization
    json_results = {}
    for key, value in results.items():
        if key == 'val_metrics':
            json_results[key] = {k: float(v) if isinstance(v, np.number) else v for k, v in value.items()}
        elif key == 'config':
            json_results[key] = value
        else:
            json_results[key] = value
    json.dump(json_results, f, indent=2)

print(f"✓ Results saved to: {results_path}")

# Close TensorBoard writer
writer.close()
print(f"✓ TensorBoard logs saved")

print("\n" + "="*80)
print("✅ ALL DONE!")
print("="*80)
print(f"\nTo view TensorBoard logs, run:")
print(f"  tensorboard --logdir {config['logging']['tensorboard_dir']}")
print("="*80)
# Out:
# ================================================================================
# SAVING RESULTS
# ================================================================================
# Results file: LSTM_bi_256h_1l_0.0003lr_d040_20251117_162952_f109291_results.json
# ✓ Results saved to: ./models/LSTM_bi_256h_1l_0.0003lr_d040_20251117_162952_f109291_results.json
# ✓ TensorBoard logs saved
#
# ================================================================================
# ✅ ALL DONE!
# ================================================================================
#
# To view TensorBoard logs, run:
#   tensorboard --logdir ./tensorboard
# ================================================================================

# %% [markdown]
# ## 14. Generate Submission
#
# Preprocess test data and generate predictions for submission.

# %%
print("\n" + "="*80)
print("GENERATING SUBMISSION")
print("="*80)

print("\n📋 Step 1: Preprocessing test data...")

# Load raw test data (already loaded in cell 2, but reload to be sure)
X_test_raw = pd.read_csv(os.path.join(data_config['raw_dir'], data_config['test_file']))
print(f"  Raw test data: {X_test_raw.shape}")

# Apply same preprocessing as training data (without labels)
from src.preprocessing.utils import preprocess_pirates_data

# Create dummy labels for preprocessing (will be ignored)
dummy_labels = pd.DataFrame({
    'sample_index': X_test_raw['sample_index'].unique(),
    'label': 'no_pain'  # Dummy label
})

X_test_processed, _ = preprocess_pirates_data(X_test_raw, dummy_labels, config, verbose=False)
print(f"  Preprocessed test data: {X_test_processed.shape}")

print("\n📐 Step 2: Normalizing test data using training statistics...")

# Verify scaler exists
if 'scaler' not in locals():
    print("  ⚠️  WARNING: Scaler not found! Re-fitting on training data...")
    print("     This should only happen if you're running this cell independently.")
    from sklearn.preprocessing import MinMaxScaler
    scaler = MinMaxScaler()
    scaler.fit(X_train_split[feature_columns])

# Get feature columns (same as training)
# CRITICAL: Only normalize the non-time features (same as training in Cell 10)
feature_columns_test = feature_columns

# Normalize test data using TRAINING statistics (NOT test statistics!)
X_test_norm = X_test_processed.copy()
X_test_norm[feature_columns_test] = scaler.transform(X_test_processed[feature_columns_test])

# Get ALL feature columns (including time features) for sequence building
all_feature_columns_test = [col for col in X_test_norm.columns if col not in ['sample_index', 'time', 'label']]

print(f"  ✓ Test data normalized using scaler from Cell 10 (training statistics)")
print(f"  Normalized features range: [{X_test_norm[feature_columns_test].min().min():.4f}, {X_test_norm[feature_columns_test].max().max():.4f}]")
print(f"  Training was normalized to: [0.0000, 1.0000]")
print(f"  Total features (including time features): {len(all_feature_columns_test)}")

print("\n🔄 Step 3: Building sequences...")

# Convert to float32
X_test_norm[all_feature_columns_test] = X_test_norm[all_feature_columns_test].astype(np.float32)

# Build sequences (no labels needed, just features)
from src.preprocessing.utils import build_sequences

# Create a temporary dataframe with dummy labels for sequence building
df_test = X_test_norm.copy()
df_test['label'] = 0  # Dummy label for sequence building

# This must match the training data feature count
X_test_seq, _ = build_sequences(
    df_test,
    window=config['sequences']['window_size'],
    stride=config['sequences']['stride'],  # Use same stride as training
    feature_columns=all_feature_columns_test  # FIXED: was feature_columns_test
)

print(f"  Test sequences: {X_test_seq.shape} (samples, timesteps, features)")
print(f"  Unique test samples: {X_test_processed['sample_index'].nunique()}")

print("\n🤖 Step 4: Making predictions with trained model...")

model.eval()
all_predictions = []

# Create test dataloader
from torch.utils.data import TensorDataset, DataLoader
test_dataset = TensorDataset(torch.from_numpy(X_test_seq).float())
test_dataloader = DataLoader(
    test_dataset, 
    batch_size=config['training']['batch_size'], 
    shuffle=False,
    num_workers=0
)

with torch.no_grad():
    for (inputs,) in test_dataloader:
        inputs = inputs.to(device)
        outputs = model(inputs)
        predictions = outputs.argmax(dim=1)
        all_predictions.append(predictions.cpu().numpy())

all_predictions = np.concatenate(all_predictions)

# Map predictions back to labels
label_mapping = {0: 'no_pain', 1: 'low_pain', 2: 'high_pain'}
predicted_labels = [label_mapping[pred] for pred in all_predictions]

print(f"  Total predictions: {len(predicted_labels)}")
print(f"  Prediction distribution:")
unique, counts = np.unique(all_predictions, return_counts=True)
for label_id, count in zip(unique, counts):
    print(f"    {label_mapping[label_id]}: {count} ({count/len(all_predictions)*100:.2f}%)")

# Step 5: Create submission DataFrame
print("\n📝 Step 5: Creating submission file...")

# Get unique sample indices from test data
# Note: With stride < window_size, we have multiple predictions per sample
# We need to aggregate them (use majority vote or first prediction)

# Build a mapping from sequence index to sample_index
sample_indices = []
for sample_id in X_test_processed['sample_index'].unique():
    sample_data = X_test_processed[X_test_processed['sample_index'] == sample_id]
    num_sequences = max(1, (len(sample_data) - config['sequences']['window_size']) // config['sequences']['stride'] + 1)
    sample_indices.extend([sample_id] * num_sequences)

# Create DataFrame with predictions
submission_df = pd.DataFrame({
    'sample_index': sample_indices,
    'label': predicted_labels
})

# If we have multiple predictions per sample (due to stride), aggregate them
if config['sequences']['stride'] < config['sequences']['window_size']:
    print(f"  ⚠️  Multiple predictions per sample detected (stride < window_size)")
    print(f"     Using majority vote to aggregate predictions...")
    
    # Majority vote per sample
    submission_df = submission_df.groupby('sample_index')['label'].agg(
        lambda x: x.value_counts().index[0]  # Most common prediction
    ).reset_index()

# Ensure we have predictions for all test samples
expected_samples = X_test_raw['sample_index'].nunique()
actual_samples = len(submission_df)

print(f"  Expected samples: {expected_samples}")
print(f"  Actual predictions: {actual_samples}")

if actual_samples != expected_samples:
    print(f"  ⚠️  WARNING: Sample count mismatch!")
else:
    print(f"  ✓ Sample count matches!")

# Save submission file
submission_path = os.path.join(config['logging']['save_dir'], f'{experiment_name}_submission.csv')
submission_df.to_csv(submission_path, index=False)

print(f"\n✅ Submission file saved to: {submission_path}")
print(f"   Shape: {submission_df.shape}")
print(f"\n📊 Submission Summary:")
print(submission_df['label'].value_counts().sort_index())

print("="*80)
print("\n💡 TIP: You can now submit this CSV file to the competition platform!")
print("="*80)
# Out:
# ================================================================================
# GENERATING SUBMISSION
# ================================================================================
#
# 📋 Step 1: Preprocessing test data...
#   Raw test data: (211840, 40)
#   Preprocessed test data: (211840, 40)
#
# 📐 Step 2: Normalizing test data using training statistics...
#   ✓ Test data normalized using scaler from Cell 10 (training statistics)
#   Normalized features range: [-0.0722, 3.4309]
#   Training was normalized to: [0.0000, 1.0000]
#   Total features (including time features): 38
#
# 🔄 Step 3: Building sequences...
# Built 41044 sequences from 1324 users
# Sequence shape: (41044, 10, 38)
#   Test sequences: (41044, 10, 38) (samples, timesteps, features)
#   Unique test samples: 1324
#
# 🤖 Step 4: Making predictions with trained model...
#   Total predictions: 41044
#   Prediction distribution:
#     no_pain: 31897 (77.71%)
#     low_pain: 5454 (13.29%)
#     high_pain: 3693 (9.00%)
#
# 📝 Step 5: Creating submission file...
#   ⚠️  Multiple predictions per sample detected (stride < window_size)
#      Using majority vote to aggregate predictions...
#   Expected samples: 1324
#   Actual predictions: 1324
#   ✓ Sample count matches!
#
# ✅ Submission file saved to: ./models/LSTM_bi_256h_1l_0.0003lr_d040_20251117_160611_submission.csv
#    Shape: (1324, 2)
#
# 📊 Submission Summary:
# label
# high_pain     111
# low_pain      176
# no_pain      1037
# Name: count, dtype: int64
# ================================================================================
#
# 💡 TIP: You can now submit this CSV file to the competition platform!
# ================================================================================
